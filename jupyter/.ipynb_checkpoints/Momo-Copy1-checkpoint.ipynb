# %%
# Cargamos datos
import Loading_data 
from matplotlib import pyplot as plt    
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %%
df = pd.read_csv('https://momo.isciii.es/public/momo/data')
df.to_csv('/tmp/momo.csv')
df.head()
# Out:
#      ambito cod_ambito  cod_ine_ambito nombre_ambito cod_sexo nombre_sexo  \
# 0  nacional        NaN             NaN           NaN      all       todos
# 1  nacional        NaN             NaN           NaN      all       todos
# 2  nacional        NaN             NaN           NaN      all       todos
# 3  nacional        NaN             NaN           NaN      all       todos
# 4  nacional        NaN             NaN           NaN      all       todos
#
#   cod_gedad nombre_gedad fecha_defuncion  defunciones_observadas  \
# 0       all        todos      2018-05-19                    1060
# 1       all        todos      2018-05-20                     970
# 2       all        todos      2018-05-21                    1000
# 3       all        todos      2018-05-22                    1005
# 4       all        todos      2018-05-23                    1082
#
#    defunciones_observadas_lim_inf  defunciones_observadas_lim_sup  \
# 0                          1060.0                          1060.0
# 1                           970.0                           970.0
# 2                          1000.0                          1000.0
# 3                          1005.0                          1005.0
# 4                          1082.0                          1082.0
#
#    defunciones_esperadas  defunciones_esperadas_q01  defunciones_esperadas_q99
# 0                 1026.5                     945.94                    1135.31
# 1                 1029.5                     945.94                    1123.58
# 2                 1031.0                     934.90                    1122.65
# 3                 1037.0                     934.90                    1136.41
# 4                 1031.5                     928.69                    1136.41

# %%
import janitor
import datetime



def pipeline_basic_with_query(df,query):
    """ Basic filtering, using janitor """
    LISTA_COLUMNAS_A_BORRAR = ['Unnamed: 0',
                           'defunciones_observadas_lim_inf',
                           'defunciones_observadas_lim_sup',
                           'defunciones_esperadas',
                           'defunciones_esperadas_q01',
                           'defunciones_esperadas_q99']
    return (
        df
        # Quitar: columnas
        .remove_columns(LISTA_COLUMNAS_A_BORRAR)
        .clean_names()
        # Enriquecer: fechas con columnas de años, mes y año-mes
        .rename_column( "fecha_defuncion", "date")
        .to_datetime('date')
        .join_apply(lambda x: x['date'].strftime('%Y')    , new_column_name="date_year"       )
        .join_apply(lambda x: x['date'].strftime('%m')    , new_column_name="date_month"      )
        .join_apply(lambda x: x['date'].strftime('%U')    , new_column_name="date_week"       )
        .join_apply(lambda x: x['date'].strftime('%Y-%m') , new_column_name="date_year_month" )
        .join_apply(lambda x: x['date'].strftime('%Y-%U') , new_column_name="date_year_week"  )
        # Filtrar:por query
        .filter_on( query )
        .set_index('date')
    )

def pipeline_basic(df):
    query = 'ambito       == "nacional" & nombre_gedad == "todos"  & nombre_sexo  == "todos"  '
    return pipeline_basic_with_query(df,query)

def pipeline_agregado_anual(periodo_de_tiempo,df,year):
    return (
        df
        .filter_on('date_year == "'+year+'"'  )
        .groupby_agg( by='date_'+periodo_de_tiempo, agg='sum', agg_column_name="defunciones_observadas", new_column_name="agregados")
        .rename_column( "agregados", year)
        .join_apply(lambda x: x['date_'+periodo_de_tiempo]  , new_column_name=periodo_de_tiempo )
        .set_index('date_'+periodo_de_tiempo)
        [[periodo_de_tiempo,year]]
        .drop_duplicates()        
    )

def pipeline_comparativa_anual(periodo_de_tiempo,df_2018,df_2019,df_2020):
    """ Mergea tres dataframes de año, por periodo de tiempo"""
    return  (
    df_2018
    .merge( df_2019, on=periodo_de_tiempo, how='right')
    .merge( df_2020, on=periodo_de_tiempo, how='left')
    .sort_naturally(periodo_de_tiempo)
    .set_index(periodo_de_tiempo)
    .join_apply(lambda x: x['2020'] - x['2019'] , new_column_name="resta 2020 y 2019"  )
    )

def extraer_defunciones_anuales_por_periodo(periodo_de_tiempo,query):
    """Extrae el cuadro de comparativa por week, or year """
    # Sacamos los datos y limpiamos
    df       = pd.read_csv('/tmp/momo.csv')
    df_basic = pipeline_basic_with_query(df,query)

    # Sacamos los datos agrupados por años
    muertes_2018  = pipeline_agregado_anual(periodo_de_tiempo,df=df_basic,year='2018')
    muertes_2019  = pipeline_agregado_anual(periodo_de_tiempo,df=df_basic,year='2019')
    muertes_2020  = pipeline_agregado_anual(periodo_de_tiempo,df=df_basic,year='2020')

    # Generamos un solo cuadro, con columna por año
    df_comparativa_años  = pipeline_comparativa_anual(periodo_de_tiempo,muertes_2018,muertes_2019,muertes_2020)
    return df_comparativa_años

#query = 'ambito       == "nacional" & nombre_gedad == "todos"  & nombre_sexo  == "todos"  '
#df_muertes_anuales_por_semana = extraer_defunciones_anuales_por_periodo("week",query)
#df_muertes_anuales_por_mes    = extraer_defunciones_anuales_por_periodo("month",query)

# %%
from matplotlib import pyplot as plt    
from IPython.display import display, HTML
import pandas as pd

import numpy as np

periodo_de_tiempo="week"
query = 'ambito       == "nacional" & nombre_gedad == "todos"  & nombre_sexo  == "todos"  '

df = extraer_defunciones_anuales_por_periodo(periodo_de_tiempo,query) 

fig = plt.figure(figsize=(8, 6), dpi=80)
plt.xticks(rotation=90)

for ca in ['2018','2019','2020']:
    plt.plot(df[ca])
    plt.legend(df.columns)
    plt.xlabel(periodo_de_tiempo)
    plt.ylabel("Deaths by " + periodo_de_tiempo)
    fig.suptitle('Comparativa de fallecimientos por año, según MOMO', fontsize=20)
plt.show()


#df['resta 2020 y 2019'] = df['2020'] - df['2019']

df.style.format({"2020": "{:20,.0f}", 
                          "2018": "{:20,.0f}", 
                          "2019":  "{:20,.0f}", 
                          "resta 2020 y 2019": "{:20,.0f}", }).background_gradient(cmap='Wistia',subset=['resta 2020 y 2019'])
# Out:
# <style  type="text/css" >
#     #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row0_col3 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row1_col3 {
#             background-color:  #ecf95f;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row2_col3 {
#             background-color:  #ebf960;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row3_col3 {
#             background-color:  #eff654;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row4_col3 {
#             background-color:  #eff654;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row5_col3 {
#             background-color:  #edf759;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row6_col3 {
#             background-color:  #ecf85d;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row7_col3 {
#             background-color:  #e9fb68;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row8_col3 {
#             background-color:  #ecf85d;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row9_col3 {
#             background-color:  #edf75a;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row10_col3 {
#             background-color:  #f7ef36;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row11_col3 {
#             background-color:  #ffcc09;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row12_col3 {
#             background-color:  #fd8d00;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row13_col3 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row14_col3 {
#             background-color:  #fe9a00;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row15_col3 {
#             background-color:  #ffba00;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row16_col3 {
#             background-color:  #ffda12;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row17_col3 {
#             background-color:  #f9ed2f;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row18_col3 {
#             background-color:  #f7ef36;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row19_col3 {
#             background-color:  #f0f550;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row20_col3 {
#             background-color:  #f2f34a;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row21_col3 {
#             background-color:  #f2f348;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row22_col3 {
#             background-color:  #e7fc6f;
#             color:  #000000;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row23_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row24_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row25_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row26_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row27_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row28_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row29_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row30_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row31_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row32_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row33_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row34_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row35_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row36_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row37_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row38_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row39_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row40_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row41_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row42_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row43_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row44_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row45_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row46_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row47_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row48_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row49_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row50_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row51_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row52_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }</style><table id="T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >2018</th>        <th class="col_heading level0 col1" >2019</th>        <th class="col_heading level0 col2" >2020</th>        <th class="col_heading level0 col3" >resta 2020 y 2019</th>    </tr>    <tr>        <th class="index_name level0" >week</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1level0_row0" class="row_heading level0 row0" >00</th>
#                         <td id="T_0f172e62_a7fb_11ea_8b4d_005056a2c6f1row0_col0" class="data row0 col0" >                 nan</td>
#                         <td id="T_0f172e62_a7

# %%
# Sacamos las muertes en madrid de hombres y de mujeres

import numpy as np 
import seaborn as sns

df       = pd.read_csv('/tmp/momo.csv')


query = 'nombre_ambito       == "Madrid, Comunidad de" & nombre_gedad == "todos"  & nombre_sexo  != "todos" &  date_year == "2019"   &  date_month < "07" '

df_madrid_2019 = pipeline_basic_with_query(df,query)
df_madrid_2019 = (
    df_madrid_2019
    .remove_columns(['nombre_gedad','ambito','cod_ambito','cod_ine_ambito','nombre_ambito','cod_sexo','cod_gedad','date_year','date_week','date_month','date_year_week'])
    .rename_column( "nombre_sexo", "sexo")
    .rename_column( "date_year_month",  "mes")
)

query = 'nombre_ambito       == "Madrid, Comunidad de" & nombre_gedad == "todos"  & nombre_sexo  != "todos" &  date_year == "2020"   &  date_month < "07" '

df_madrid_2020 = pipeline_basic_with_query(df,query)
df_madrid_2020 = (
    df_madrid_2020
    .remove_columns(['nombre_gedad','ambito','cod_ambito','cod_ine_ambito','nombre_ambito','cod_sexo','cod_gedad','date_year','date_week','date_month','date_year_week'])
    .rename_column( "nombre_sexo", "sexo")
    .rename_column( "date_year_month",  "mes")
)

df_madrid_2019
# Out:
#                sexo  defunciones_observadas      mes
# date
# 2019-01-01  hombres                      60  2019-01
# 2019-01-02  hombres                      55  2019-01
# 2019-01-03  hombres                      63  2019-01
# 2019-01-04  hombres                      62  2019-01
# 2019-01-05  hombres                      55  2019-01
# ...             ...                     ...      ...
# 2019-06-26  mujeres                      48  2019-06
# 2019-06-27  mujeres                      48  2019-06
# 2019-06-28  mujeres                      56  2019-06
# 2019-06-29  mujeres                      46  2019-06
# 2019-06-30  mujeres                      53  2019-06
#
# [362 rows x 3 columns]

# %%
warnings.filterwarnings('ignore')
from IPython.display import display, HTML

display(HTML("<h2>Distribucion muertes en Madrid, 2019 </h2>"))
display(HTML("Seis primeros meses."))
    
    
import seaborn as sns
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x="mes", y="defunciones_observadas", hue="sexo",
                    data=df_madrid_2019,  split=True,
                    scale="count")
# Out:
# <h2>Distribucion muertes en Madrid, 2019 </h2>
# Seis primeros meses.

# %%
import seaborn as sns
display(HTML("<h2>Distribucion muertes en Madrid, 2020 </h2>"))



sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x="mes", y="defunciones_observadas", hue="sexo",
                    data=df_madrid_2020,   split=True,
                    scale="count")
# Out:
# <h2>Distribucion muertes en Madrid, 2020 </h2>

# %%
# Aux functions
def print_categorical_variables(df):
    """ Get a dict with categorical variables"""    
    my_dict = {}
    cols = df.columns
    num_cols = df._get_numeric_data().columns
    # Show categorical values
    categorical = list(set(cols) - set(num_cols))
    for i in categorical : 
        if 'echa' not in i.lower() : my_dict[i] = df[i].unique()         
    return my_dict
df = get_momo()
my_dict = print_categorical_variables(df)
my_dict
# Out:
# {'cod_ambito': array([nan, 'AN', 'AR', 'AS', 'IB', 'CN', 'CB', 'CL', 'CM', 'CT', 'VC',
#         'EX', 'GA', 'MD', 'MC', 'NC', 'PV', 'RI', 'CE', 'ML'], dtype=object),
#  'cod_sexo': array(['all', '1', '6'], dtype=object),
#  'nombre_sexo': array(['todos', 'hombres', 'mujeres'], dtype=object),
#  'cod_gedad': array(['all', 'menos_65', '65_74', 'mas_74'], dtype=object),
#  'nombre_ambito': array([nan, 'Andalucía', 'Aragón', 'Asturias, Principado de',
#         'Balears, Illes', 'Canarias', 'Cantabria', 'Castilla y León',
#         'Castilla - La Mancha', 'Cataluña', 'Comunitat Valenciana',
#         'Extremadura', 'Galicia', 'Madrid, Comunidad de',
#         'Murcia, Región de', 'Navarra, Comunidad Foral de', 'País Vasco',
#         'Rioja, La', 'Ceuta', 'Melilla'], dtype=object),
#  'nombre_gedad': array(['todos', 'edad < 65', 'edad 65-74', 'edad > 75'], dtype=object),
#  'ambito': array(['nacional', 'ccaa'], dtype=object)}
